# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-2*np.pi,2*np.pi,0.01)
y = np.sin(10*x)/x
plt.title('function')
plt.xlabel('xlabel',fontsize=20)
plt.ylabel('ylabel')
plt.xticks(color='blue')
plt.legend(['First'],loc=1)
plt.grid(True)
plt.yticks([10],[r'$+2\pi$'])
plt.xticks([-2,2],[r'$-\pi$',r'$+2\pi$'])

ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))


plt.plot(x,y,'c',linewidth=3)

# %%
import matplotlib.pyplot as plt 
import numpy as np 

pop = np.random.randint(0,100,100)
n,bins,patches = plt.hist(pop,bins=20)

# %%
bins
# Out:
# array([ 2.  ,  6.85, 11.7 , 16.55, 21.4 , 26.25, 31.1 , 35.95, 40.8 ,
#        45.65, 50.5 , 55.35, 60.2 , 65.05, 69.9 , 74.75, 79.6 , 84.45,
#        89.3 , 94.15, 99.  ])

# %%
import numpy as np
index = np.arange(5)
values = [7,4,8,2,9]
std = [0.8,1,0.4,0.9,1.2]
plt.barh(index,values,xerr=std,error_kw={'ecolor':'0.1','capsize':6},
        alpha=0.9,label='First')
plt.yticks(index,['A','B','C','D','E'])
plt.legend(loc=5)

# %%
import matplotlib.pyplot as plt 
import numpy as np
dx = 0.01;dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(X,Y):
    return (1 - Y**5 + X**5)*np.exp(-X**2 - Y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8,cmap=plt.cm.hot)
plt.clabel(C,inline=1,fontsize=10)
plt.colorbar()

# %%
import matplotlib.pyplot as plt 
import numpy as np

N = 8
theta = np.arange(0.,2 * np.pi, 2* np.pi / N)  #角度
radii = np.array([4,7,5,3,0,5,6,7])  #半径
plt.axes([0.025,0.025,0.95,0.95],polar=True)   #重点，不写是条状图，指定显示范围
colors = np.array(['red','green','yellow','#4bb2c5','blue','black','#839577','#EAA228'])
bars = plt.bar(theta,radii,width=(2*np.pi/N),bottom=0.0,color=colors)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()   #构架一个figure对象
ax = Axes3D(fig)  #以fogur对象为参数，构建axes对象
x = np.arange(-2,2,0.1)
y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(x,y)  #网格
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y),rstride=3,cstride=3,cmap=plt.cm.hot)  #步幅
# ax.view_init(elev=30,azim=125)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()   #构架一个figure对象
ax = Axes3D(fig)  #以fogur对象为参数，构建axes对象
x = np.arange(-2,2,0.1)
y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(x,y)  #网格
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=1,cmap=plt.cm.hot)  #步幅

# %%
# %time a = range(10)
# Out:
# Wall time: 0 ns

# %%
# %%timeit a = range(10)
min(a)
# Out:
# 332 ns ± 27.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
import numpy as np
data = np.random.randint(0,10,size=(3,3)).astype(np.float)
# data[2,2],data[1,1] = np.nan,np.nan
# # data[~np.isnan(data)]
data[(1,1),(1,2)] = np.NAN
data
# Out:
# array([[ 9.,  2.,  1.],
#        [ 7., nan, nan],
#        [ 2.,  8.,  8.]])

# %%
lines = np.where(np.isnan(data))[0]
print(data)
lines
# Out:
# [[ 9.  2.  1.]
#  [ 7. nan nan]
#  [ 2.  8.  8.]]
# array([1, 1], dtype=int64)

# %%
np.delete(data,lines,axis=0)
# Out:
# array([[9., 2., 1.],
#        [2., 8., 8.]])

# %%
# import numpy as np
# import pandas as pd 
# data = np.random.randint(1,10,size=(5,3))
# ddate = pd.DataFrame(data,columns=['数学','英语','语文'])
# ddate.index.name = 'index'
# print(ddate)

# ddate.to_csv('scrores.cvs',index=False)
# Out:
#        数学  英语  语文
# index
# 0       4   7   1
# 1       9   6   4
# 2       4   7   4
# 3       4   5   1
# 4       1   7   9

# %%
import numpy as np
import pandas as pd 
scores = np.loadtxt('data.csv',skiprows=1,delimiter=',',dtype=np.str)
scores
# Out:
# array([['45', '63'],
#        ['20', ''],
#        ['', '12'],
#        ['52', '32.5']], dtype='<U4')

# %%
scores[scores == ""] = np.NAN
scores1 = scores.astype(np.float)
scores1[np.isnan(scores1)] = 0
scores1.sum(axis=1)
# Out:
# array([108. ,  20. ,  12. ,  84.5])

# %%
scores2 = scores.astype(np.float)
for x in range(scores2.shape[1]):
    col = scores2[:,x]
    mean =  col[~np.isnan(col)].mean()
    col[np.isnan(col)] = mean
scores2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bc9603ef12bb> in <module>
# ----> 1 scores2 = scores.astype(np.float)
#       2 for x in range(scores2.shape[1]):
#       3     col = scores2[:,x]
#       4     mean =  col[~np.isnan(col)].mean()
#       5     col[np.isnan(col)] = mean
#
# NameError: name 'scores' is not defined

# %%
import numpy as np
import pandas as pd 

values = [12,23,98,35,85,28,45]
bins = [10,30,60,100]
names = ['tone','wtwo','tthree']
cvalues = pd.cut(values,bins = 3,labels=names)
# pd.value_counts(cvalues)
# cvalues.categories
cvalues


random_values = np.random.random(100)
random_values.sum()
# Out:
# 50.108597109843764

# %%
c = pd.cut(random_values,10,precision=2).categories
pd.value_counts(c)
# Out:
# (0.0053, 0.1]    1
# (0.2, 0.3]       1
# (0.59, 0.69]     1
# (0.89, 0.99]     1
# (0.4, 0.5]       1
# (0.3, 0.4]       1
# (0.79, 0.89]     1
# (0.1, 0.2]       1
# (0.5, 0.59]      1
# (0.69, 0.79]     1
# dtype: int64

# %%
datas = np.random.rand(1000).reshape(250,4)
d_datas = pd.DataFrame(datas)
d_datas
# Out:
#             0         1         2         3
# 0    0.492686  0.572992  0.276867  0.858374
# 1    0.031371  0.873235  0.260206  0.865076
# 2    0.682816  0.876430  0.973817  0.683870
# 3    0.530190  0.451138  0.333208  0.854330
# 4    0.636969  0.467492  0.897285  0.595932
# 5    0.336709  0.056910  0.967471  0.534307
# 6    0.293863  0.417669  0.042618  0.815164
# 7    0.535398  0.220753  0.869160  0.929176
# 8    0.916675  0.586753  0.539545  0.079055
# 9    0.171630  0.667310  0.876533  0.962678
# 10   0.884028  0.471805  0.143029  0.484222
# 11   0.663942  0.103881  0.933840  0.327226
# 12   0.560296  0.021776  0.447876  0.505460
# 13   0.162122  0.646568  0.789210  0.639015
# 14   0.734599  0.411618  0.732948  0.644891
# 15   0.405374  0.730577  0.068765  0.168699
# 16   0.619589  0.073224  0.290920  0.563915
# 17   0.785705  0.965968  0.557771  0.844143
# 18   0.074049  0.664049  0.320917  0.211970
# 19   0.753789  0.730376  0.316751  0.004118
# ...

# %%
datas[(np.abs(d_datas) > 0.9).any(1)]
# Out:
# array([[4.92685630e-01, 5.72992334e-01, 2.76866774e-01, 7.00000000e+00],
#        [3.13708604e-02, 7.00000000e+00, 2.60205764e-01, 7.00000000e+00],
#        [6.82816389e-01, 7.00000000e+00, 7.00000000e+00, 6.83870072e-01],
#        [5.30190172e-01, 4.51138427e-01, 3.33208217e-01, 7.00000000e+00],
#        [6.36968909e-01, 4.67491549e-01, 7.00000000e+00, 5.95932387e-01],
#        [3.36708793e-01, 5.69098739e-02, 7.00000000e+00, 5.34306548e-01],
#        [2.93863046e-01, 4.17669082e-01, 4.26180410e-02, 7.00000000e+00],
#        [5.35397848e-01, 2.20753341e-01, 7.00000000e+00, 7.00000000e+00],
#        [7.00000000e+00, 5.86752631e-01, 5.39545351e-01, 7.90545303e-02],
#        [1.71630148e-01, 6.67310052e-01, 7.00000000e+00, 7.00000000e+00],
#        [7.00000000e+00, 4.71804837e-01, 1.43029314e-01, 4.84221990e-01],
#        [6.63942343e-01, 1.03880966e-01, 7.00000000e+00, 3.27226175e-01],
#        [1.62122434e-01, 6.46568007e-01, 7.00000000e+00, 6.39015409e-01],
# ...

# %%
d_datas[np.abs(datas) > 0.9] = 10
d_datas.describe()
# Out:
#                 0           1           2           3
# count  250.000000  250.000000  250.000000  250.000000
# mean     3.026346    3.607155    3.331408    3.102473
# std      4.318391    4.559605    4.460882    4.356230
# min      0.000941    0.007858    0.003677    0.003060
# 25%      0.268859    0.303337    0.288790    0.248566
# 50%      0.521542    0.563880    0.504262    0.521222
# 75%     10.000000   10.000000   10.000000   10.000000
# max     10.000000   10.000000   10.000000   10.000000

# %%
data = pd.DataFrame(np.arange(10).reshape(5,2))
print(data)
new_order = np.random.permutation(5)
data1 = data.take(new_order)
data1.sample(10,replace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c7901eb23b97> in <module>
# ----> 1 data = pd.DataFrame(np.arange(10).reshape(5,2))
#       2 print(data)
#       3 new_order = np.random.permutation(5)
#       4 data1 = data.take(new_order)
#       5 data1.sample(10,replace=True)
#
# NameError: name 'pd' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn import datasets
np.random.seed(0)
iris = datasets.load_iris()
x = iris.data
y = iris.target
i = np.random.permutation(len(iris.data))

x_train = x[i[:-10]]
y_train = y[i[:-10]]
x_test = x[i[-10:]]
y_test = y[i[-10:]]

knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

knn.predict(x_test)
# Out:
# array([1, 2, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
y_test
# Out:
# array([1, 1, 1, 0, 0, 0, 2, 1, 2, 0])

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from matplotlib.colors import ListedColormap

iris = datasets.load_iris()
x = iris.data[:,:2]
y = iris.target

x_min,x_max = x[:,0].min() - .5,x[:,0].max() + .5
y_min,y_max = y[:,1].min() - .5,y[:,1].max() + .5
cmap_list = ListedColormap(['#AAAAFF','#AAFFAA','#FFAAAA'])
h = 0.2
xx,yy = np.meshgrid(np.arange(x_min,x_max,h),np.arange(y_min,y_max,h))

knn = KNeighborsClassifier()
knn.fit(x,y)
Z = knn.predict(np.c_[xx.ravel(),yy.ravel()])
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx,yy,Z,cmap=cmap_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-e7748f05e8b7> in <module>
#      10
#      11 x_min,x_max = x[:,0].min() - .5,x[:,0].max() + .5
# ---> 12 y_min,y_max = y[:,1].min() - .5,y[:,1].max() + .5
#      13 cmap_list = ListedColormap(['#AAAAFF','#AAFFAA','#FFAAAA'])
#      14 h = 0.2
#
# IndexError: too many indices for array

# %% [markdown]
# #数据清洗

# %%
strs = 'a,b, c'
# p = [x.strip() for x in strs.split(',')]
# # p
# strs.replace(',',':')
# ": ".join(strs)
strs.find('c')
strs.index('c')
# Out:
# 5

# %%
import re 
strs = 'python /learni/ng \ '
re.search('a',strs).group()
re.findall('\s+',strs)
re.split('/',strs)
re.sub('\s+','::',strs)
# Out:
# 'python::/learni/ng::\\::'

# %%
import pandas as pd
import numpy as np
dict = {
   'a':'www.123@.qq.com','b':'adkk;sd@com','c':np.nan
}
ser = pd.Series(dict)
ser.isnull()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
# ser.map(lambda x:x.split('@'))
# ser.str.split('@')
ser.str.contains('qq')
# Out:
# a     True
# b    False
# c      NaN
# dtype: object

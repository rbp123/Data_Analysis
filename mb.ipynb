# %%
from matplotlib import pyplot as plt
import numpy as np 
import pandas as pd
from matplotlib import font_manager

# %%
y1 = [np.random.randint(0,50) for x in range(10)]
y2 = [np.random.randint(0,50) for x in range(10)]
x = range(5,15)
#识别中文，构建font
font = font_manager.FontProperties(fname=r"C:\Windows\Fonts\msyh.ttc")

#设置图的大小 
plt.figure(figsize=(15,5))

#对line2D 对象的操作  线对象
lines = plt.plot(x,y1,x,y2)
second_line = lines[1]
first_line = lines[0]
first_line.set_color('b')
first_line.set_alpha(0.5)
first_line.set_linewidth(4)
first_line.set_marker("o")

second_line.set_marker('^')

font.set_size(12) #重置字体大小
plt.title("折线图",fontproperties=font,size=30) #识别中文，传入参数
plt.setp(lines,c='r')
plt.xticks(range(5,15),["第%s天" %x for x in range(1,11)],fontproperties=font)  #x轴的刻度
# font.set_size(30)
plt.xlabel('天数',fontproperties=font,size=30)  #x轴的标签
plt.ylabel('票房/万元',fontproperties=font,size=30)
plt.grid(True)  # 网格

# %%
mydata = {
    'x':range(10,20),
    'y':[np.random.randint(0,20) for x in range(10)]
}
mydf = pd.DataFrame(data=mydata)

# 创建figure对象，地需在其前面
plt.figure(figsize=(10,5),facecolor='r',edgecolor='k',linewidth=10)
plt.plot('x','y','',color="r",marker='o',data=mydf,markerfacecolor='g') #不会有歧义，不警告

#Axes 对象 中间有图部分
ax = plt.gca()
ax.set_facecolor('y')  #设置表面颜色

plt.title("hahaha",size=16)
plt.legend()

# 添加注射和箭头
for x in range(10):
    plt.annotate("(%d,%d)" %(mydata['x'][x],mydata['y'][x]),xy=(mydata['x'][x],mydata['y'][x]),xytext=(mydata['x'][x]-1,mydata['y'][x]-1),
                arrowprops={'width':2,'headwidth':20,'headlength':5,'shrink':0.1})

# %%
import numpy as np
values = np.linspace(0,20)
plt.style.use('ggplot')
plt.subplot(2,2,1)
plt.plot(values,c='k')
plt.plot(values**2,'g--')
plt.subplot(2,2,2)
plt.plot(np.sin(values),c='r')
plt.subplot(2,2,3)
plt.plot(np.cos(values),c='y')
plt.subplot(2,2,4)
plt.plot(np.tan(values),c='b')

figure,Axes = plt.subplots(2,2,sharex=True)
ax = Axes[0,0]
ax.plot(np.exp(values),c='r')
ax.plot(values**2,c='y')
ax = Axes[0,1]
ax.plot(np.sin(values),c='g')
ax = Axes[1,0]
ax.plot(np.cos(values),c='k')
ax = Axes[1,1]
ax.plot(np.log(values),c='y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65145eb481f3> in <module>
#       1 import numpy as np
#       2 values = np.linspace(0,20)
# ----> 3 plt.style.use('ggplot')
#       4 plt.subplot(2,2,1)
#       5 plt.plot(values,c='k')
#
# NameError: name 'plt' is not defined

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30],
         [0, -1],
         slice(100, 200, 3),
         0.1,
         0.3,
         1.5,
         (0.0, 0.1),
         (0.45, 0.1)]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2 * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Support for axes.prop_cycle cycler with markevery')

plt.show()

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
months = mdates.MonthLocator()   #月定为器
days  = mdates.DayLocator()      #日定位器
timeFmt = mdates.DateFormatter('%y-%m-%d') 
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),datetime.date(2015,2,21),
          datetime.date(2015,3,15),datetime.date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings = [12,22,25,20,18,15,17,14]
fig,ax = plt.subplots() #创建一个figure和一系列子图
plt.plot(events,readings) #生成图像
ax.xaxis.set_major_locator(months) #x轴标注月标签
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days) #日标签，没显示

# %%
import matplotlib.pyplot as plt 
import numpy as np
#生成x的取值
x = np.arange(-2*np.pi,2*np.pi,0.01)
y1 = np.sin(3*x)/x
y2 = np.sin(2*x)/x
y3 = np.sin(1*x)/x
#画图
plt.plot(x,y1,'r--',linewidth=3)
plt.plot(x,y2,'m-.') #洋红色
plt.plot(x,y3,color='#87a3cc',linestyle='--')

#修改轴标签
plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],   
           [r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$']) #\起隔离作用
plt.yticks([-1,0,+1,+2,+3],[r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])

#添加注释
plt.annotate(r'$\lim_{x\to 0}\frac{\sin(x)}{x}=1$',xy=[0,1],xycoords='data',  #frac是分数的缩写
            xytext=[30,30],fontsize=16,
             textcoords='offset points',arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=.2")
            ) 

#生成轴对象
ax = plt.gca() 
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]    
}
df = pd.DataFrame(data)
print(df)
x = np.arange(5)
plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data,loc=2)
# Out:
#    series1  series2  series3
# 0        1        2        3
# 1        3        4        2
# 2        4        5        3
# 3        3        2        1
# 4        5        4        3

# %%
import  pandas as pd 
import  matplotlib.pyplot as plt
from matplotlib import font_manager

font = font_manager.FontProperties(fname=r"C:\Windows\Fonts\msyh.ttc",size=12)
s_data = {
    '人间四月天':25,
    '树先生':89,
    '放羊娃的春天':56,
    '加入爱有天意':45,
    '都很好':70
}
df = pd.DataFrame(data={'movies':list(s_data.keys()),'dollar':list(s_data.values())})
plt.figure(figsize=(10,5))
# plt.bar(list(s_data.keys()),list(s_data.values()),width=0.5,align='center',bottom=0,color='r',edgecolor='k',linewidth=4)
ax = plt.gca()
ax.set_facecolor('b')
ax.set_alpha(0.1)
plt.bar('movies','dollar',data=df,width=0.5,color='r')
plt.yticks(range(0,100,10),["%d亿" %x for x in range(0,100,10)],fontproperties=font,size=14)
plt.xticks(fontproperties=font,size=12)
plt.ylabel("票房",size=20,fontproperties=font,color='b')
plt.title('电影票房对比图',size=30,fontproperties=font,color='y')
# Out:
# Text(0.5, 1.0, '电影票房对比图')

# %%
data = pd.read_csv('html.csv')
# print(data)
plt.plot(data['签约均价（元/㎡）'])

# %% [markdown]
# # 作业 2

# %%
data = {
    '大学':[12,23,21,24],
    '高中':[23,25,10,22],
    '初中':[23,21,36,33]
}
df = pd.DataFrame(data,index=range(2016,2020))
plt.figure(figsize=(10,5))
xticks = df.index
bar_width = 0.2
for index,value in enumerate(df.columns):
    num = df[value]
    xtick = xticks + (index-1)*bar_width
    plt.bar(xtick,num,width=bar_width,label=value)   
    for x,y in zip(xtick,num):
        plt.annotate(y,xy=[x,y],xytext=(x-0.07,y+0.1),size=12)
        
plt.xticks(xticks) 
plt.ylim(top=45,bottom=5)
plt.ylabel('万/人',fontproperties=font,rotation="horizontal",size=12)
plt.gca().yaxis.set_label_coords(-0.02,1.03)
plt.yticks(size=15)

plt.title('2016-2019年学校招生人数直方图',fontproperties=font,size=20,color='r')
plt.legend(prop=font,ncol=3,loc=1)
plt.grid(color='k',linewidth=1,alpha=0.3)

# %% [markdown]
# 直方图=======

# %%
import matplotlib.pyplot as plt
import numpy as np 
pop = np.random.randint(0,100,100)
pop
n,bins,patches = plt.hist(pop,bins=20) #。箱子   hist数

# %%
import random 
data_list = [random.randint(100,200) for x in range(50)]
plt.figure(figsize=(15,5))
nums,bins,patches = plt.hist(data_list,bins=10,edgecolor='k',color='b',density=True,cumulative=True)
plt.xticks(bins,bins)
plt.show()

# %% [markdown]
# # =====条状图

# %%
index = [0,1,2,3,4]
values =[5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.bar(index,values,yerr=std1,error_kw={'ecolor':'0.1','capsize':6},
        alpha=0.7,label='First')  #函数bar()
plt.title('A Bar Chart')
plt.xticks(index + [0.4],['A','B','C','D','E'])
plt.legend(loc=2)

# %% [markdown]
# 水平条状图

# %%
import matplotlib.pyplot as plt 
import numpy as np
index = np.arange(5)
values = [5,7,3,4,6]
std1 = [0.8,1,0.4,0.9,1.3]
plt.title('A Horizontal Bar Chart')
#函数barh
plt.barh(index,values,xerr=std1,error_kw={'eclor':'0.1','capsize':6},alpha=0.7,label='First')
plt.yticks(index + [0.4],['A','B','C','D','E'])
plt.legend(loc=5)

# %% [markdown]
# ====多序列条状图

# %%
import matplotlib.pyplot as plt
import numpy as np 
index  = np.arange(5)
values1 = [5,7,3,4,6]
values2 = [6,6,4,5,7]
values3 = [5,6,5,4,6]
bw = 0.15
plt.axis([0,5,0,8])
plt.title('A Multiseriser Bar Chart',fontsize=20)
plt.bar(index,values1,bw,color='b')
plt.bar(index+bw,values2,bw,color='r')
plt.bar(index+2*bw,values3,bw,color='g')
plt.xticks(index+1.5*bw,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x285fe270048>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# 为=====pandas DataFrame 生成多序列条状图

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df.plot(kind='bar')  #重点部分

# %% [markdown]
# 多序列堆积条状图

# %%
series1 = np.array([3,4,5,3])
series2 = np.array([1,2,2,5])
series3 = np.array([2,3,3,4])
index = np.arange(4)
plt.axis([0,15,0,4])
plt.barh(index+0.4,series1,color='w',hatch='xx')
plt.barh(index+0.4,series2,color='w',hatch='///',left=series1) #重点部分  bottom 改left
plt.barh(index+0.4,series3,color='w',hatch='\\\\\\',left=(series1+series2))
plt.yticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
# Out:
# ([<matplotlib.axis.YTick at 0x294843149e8>,
# ...
#  <a list of 4 Text yticklabel objects>)

# %% [markdown]
# =====为pandas DataFrame 绘制堆积挑张图

# %%
import matplotlib.pyplot as plt 
import pandas as pd
data  = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,1]
}
df = pd.DataFrame(df)
df.plot(kind='bar',stacked=True)  #重点部分 堆积的

# %%
#其他的条状图

# %%
import matplotlib.pyplot as plt
import numpy as np
x0 = np.arange(8)
y1 = np.array([1,3,4,6,4,3,2,1])
y2 = np.array([1,2,5,4,3,3,2,1])
plt.ylim(-7,7) #y轴的限制范围
plt.bar(x0,y1,0.9,facecolor='r',edgecolor='w') #edgecolor
plt.bar(x0,-y2,0.9,facecolor='b',edgecolor='w')
plt.xticks(()) #x轴区空
plt.grid(True) #网格
for x,y in zip(x0,y1): # 重点部分
    plt.text(x,y + 0.05,'%d' % y,ha='center',va= 'bottom')
for x,y in zip(x0,y2):
    plt.text(x,-y - 0.05,'%d' % y,ha='center',va ='top')

# %%
#饼图

# %%
#都是重点
labels = ['Nokia','Samsung','Apple','lumia'] #各部分的标签
values = [10,30,45,15]  #各部分的数值
# colors = ['yellow','green','red','blue'] #各部分的颜色
explode = [0.3,0,0,0]  #各部分的分离度
plt.title('A Pie Chart')
patches,texts,auottexts = plt.pie(values,labels=labels,explode=explode,
        shadow=True,autopct='%1.2f%%',radius=1) #旋转角度,添加影印，添加百分比
# plt.axis('equal') #关键指点
plt.legend(loc=1)
patches[0].set_color('k')
for text in auottexts:
    text.set_color('w')
    text.set_size(12)

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

iris = datasets.load_iris()
datas = iris.data
col_index = ['petal length','petal width','sepal length','sepal width']
flower_name = ['versicolor','virginica','setosa']

dfs = pd.DataFrame(data=datas,columns=col_index)
#创建箱线图
# for col in col_index:
#     df_list=[]
#     for x  in range(3):
#         y = 50*x
#         z = 50*(1+x)
#         df = dfs[col][y:z]
#         df_list.append(df)
#     plt.figure(figsize=(5,3))
#     dt = plt.boxplot(df_list,vert=True,meanline=True,showmeans=True,notch=True)
#     plt.title(col,size=20)
#     plt.xticks(range(1,4),flower_name,size=15)
#     if dt['fliers']:
#         for x in range(len(dt['fliers'])):
#             filer = dt['fliers'][x]
#             filer.set_markerfacecolor('red')
#             filer.set_markersize(7)
#     if dt['caps']:
#         for x in range(len(dt['caps'])):
#             filer = dt['caps'][x]
#             filer.set_color('b')
#     if dt['whiskers']:
#         for x in range(len(dt['whiskers'])):
#             filer = dt['whiskers'][x]
#             filer.set_color('g')
#     if dt['boxes']:
#         for x in range(len(dt['boxes'])):
#             filer = dt['boxes'][x]
#             filer.set_color('red')
#             filer.set_linewidth(1)    
#     plt.show()

# 多表合计训练
length = dfs[['petal length','sepal length']]
le  = length.head(50)
widths = (4,1)
lengths =(1,4)
fig = plt.figure()
gs = fig.add_gridspec(2,2,width_ratios=widths,height_ratios=lengths)
ax1 = fig.add_subplot(gs[0,0])
ax1.hist(le['petal length'],bins=10)
for tick in ax1.xaxis.get_major_ticks():
    tick.label1On = False

ax2 = fig.add_subplot(gs[1,0])
ax2.scatter('petal length','sepal length',data=le,c='r')
ax2.set_ylim(0.8,2)
for tick in ax2.yaxis.get_major_ticks():
    tick.tick2On = True
for tick in ax2.xaxis.get_major_ticks():
    tick.tick2On = True
    
ax3 = fig.add_subplot(gs[1,1])
ax3.hist('sepal length',data=le,bins=10,orientation="horizontal",color='y')
ax3.set_ylim(0.8,2)
for tick in ax3.yaxis.get_major_ticks():
    tick.label1On = False
    
fig.tight_layout(w_pad=0,h_pad=0)
plt.show()

# %% [markdown]
# # 雷达图的创建

# %%
# 1. 基本创建
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager

font = font_manager.FontProperties(fname=r"C:\Windows\Fonts\msyh.ttc",size=12)
labels =['团战','KDA','生存','发育','输出']
values = [45,60,95,50,84,45]
theta = np.linspace(0,2*np.pi,6)
plt.polar(theta,values)
plt.fill(theta,values,c='b')
plt.xticks(theta,labels=labels,fontproperties=font)
plt.title("王者荣耀菜鸡雷达图",fontproperties=font,size=20)
# plt.show()

# 2.plt.subplot 绘制子图
ax = plt.subplot(111,projection='polar')
ax.plot(theta,values)
# plt.show()

# 3, plt.subplots 绘制子图
fig,Axes = plt.subplots(1,1,subplot_kw={'projection':'polar'})
Axes.plot(theta,values)
# plt.show()

# 3. fig.add_subplot 绘制雷达子图
fig = plt.figure(figsize=(5,5))
axes = fig.add_subplot(111,polar=True)
axes.plot(theta,values)
plt.show()
# Out:
# D:\anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# 2.plt.subplot 绘制子图
ax = plt.subplot(111,projection='polar')
ax.plot(theta,values)
plt.show()

# %%
# 3, plt.subplots 绘制子图
fig,Axes = plt.subplots(1,1,subplot_kw={'projection':'polar'})
Axes.plot(theta,values)
plt.show()

# %%
# 3. fig.add_subplot 绘制雷达子图
fig = plt.figure(figsize=(5,5))
axes = fig.add_subplot(111,polar=True)
axes.plot(theta,values)
plt.show()

# %% [markdown]
# # 绘双 y 轴 和axis对象

# %%
fig = plt.figure()
axes = fig.add_subplot(111)
axes.plot(np.random.rand(5)*100,label='温度',c='r')

# 克隆axes共享x 轴
axes2 = axes.twinx()
axes2.bar(range(0,5),np.random.randint(0,100,5),alpha=0.5,label='降水量')
fig.legend(prop=font,ncol=2,loc="upper center")

#设置y轴的label的位置和方向
axes.set_ylabel('温度',fontproperties=font,rotation="horizontal",color='r',size=15)
axes.yaxis.set_label_coords(-0.03,1,)

# axes.set_xlim(-2,6)
# axes.set_ylim(-10,110)
# axes.set_xticks(range(0,5)
    
plt.show()

# %%
from matplotlib import ticker
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(np.random.rand(5)*100,label="温度")
# ax.set_xlim(-12,30)
#设置y轴的label
ax.set_ylabel('湿度',rotation="horizontal",fontproperties=font)
ax.yaxis.set_label_coords(-0.02,1.1)
ax.legend(prop=font)
#x轴的标签ticklabels的设置
for xtick in ax.xaxis.get_ticklabels():
    xtick.set_color('red')
    xtick.set_rotation(45)
    xtick.set_fontsize(15)
    
# #获取当钱axes对象
# axes = plt.gca()
# print(axes)
# ax2 = fig.add_subplot(2,2,2)
# ax2.bar(range(5),np.random.randint(5))
# print(plt.gca())
# plt.sca(ax)  #设置当前axes对象
# print(plt.gca())
# fig.delaxes(ax2)  # 删除axes对象
# print(fig.axes) #获取所有的axes对象

#y轴的主标签格式设置
formatter = ticker.FormatStrFormatter("$%.2f")
ax.yaxis.set_major_formatter(formatter)
#y轴的marker格斯设置
for yline in ax.yaxis.get_ticklines():
    yline.set_color('red')
    yline.set_markeredgewidth(2)  
# ax.text(2,100,"你好",fontproperties=font)
#显示axes的其他ticklines
ax.minorticks_on()

#设置label和tick的位置，x轴的类似
for tick in ax.yaxis.get_major_ticks():
    tick.label1On = False
    tick.label2On = True
    tick.tick1On = False
    tick.tick2On = True
plt.show()

# %% [markdown]
# # 多图调整

# %%
def create_chart(ax,fontsize=12):
    """创建表"""
    ax.plot([1,3])
    ax.set_ylabel('ylabel',fontsize=fontsize)
    ax.set_xlabel('xlabel',fontsize=fontsize)
    ax.set_title('chart',fontsize=fontsize)
    
fig = plt.figure()
for x in range(4):
    ax = fig.add_subplot(2,2,x+1)
    create_chart(ax)
#调整
# fig.tight_layout(w_pad=2,h_pad=2)  #height,width
#作用一样subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)
fig.subplots_adjust(0,0,1,1,wspace=0.3,hspace=0.5)

# %%
# help(plt.figure().subplots_adjust)

# %%
import pandas as pd
data = {
    'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]
}
df = pd.DataFrame(data)
df['series1'].plot(kind='pie',figsize=(6,6))

# %%
#高级图标，等值线图

# %%
import matplotlib.pyplot as  plt
import numpy as np
dx = 0.01;dy = 0.01 # x和y的步长
x = np.arange(-2.0,2.0,dx) #确定x的取值范围
y = np.arange(-2.0,2.0,dy) 
X,Y = np.meshgrid(x,y) #用于生成网格采样点的函数。
def f(x,y):#计算z的值
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)

C = plt.contour(X,Y,f(X,Y),8,colors='black') #轮廓，8轮廓条线，颜色是黑色
plt.contourf(X,Y,f(X,Y),8) #轮廓线
plt.clabel(C,inline=1,fontsize=10) ##轮廓标签，内联的，大小10
plt.colorbar()

# %%
#3D 曲面

# %%
from mpl_toolkits.mplot3d import Axes3D #在重点
import matplotlib.pyplot as plt 
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y),rstride=1,cstride=1,cmap=plt.cm.hot) 
ax.view_init(elev=30,azim=125) #海拔高度，

# %%
xs = np.random.randint(30,40,100)
ys  = np.random.randint(20,30,100)
zs = np.random.randint(10,20,100)
xs2 = np.random.randint(50,60,100)
ys2 = np.random.randint(30,40,100)
zs2 = np.random.randint(50,70,100)
xs3 = np.random.randint(10,30,100)
ys3 = np.random.randint(40,50,100)
zs3 = np.random.randint(40,50,100)
fig = plt.figure()
ax = Axes3D(fig)  #创建3D Axes的对象
ax.scatter(xs,ys,zs,c='y')
ax.scatter(xs2,ys2,zs2,c='r',marker='^') #重点
ax.scatter(xs3,ys3,zs3,c='g',marker='*')
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')
# Out:
# Text(0.5, 0, 'Z label')

# %%
#3D条状图

# %%
import  matplotlib.pyplot as plt
import numpy as  np
from mpl_toolkits.mplot3d import Axes3D
x  = np.arange(8)
y = np.random.randint(0,10,8)
y2 = y + np.random.randint(0,3,8)
y3 = y2 + np.random.randint(0,3,8)
y4 = y3 + np.random.randint(0,3,8)
y5 = y4 + np.random.randint(0,3,8)
clr = ['#4bb2c5','#c5b47f','#EAA228','#579557','#839557','#958c12','#953579','#4b5de4']
fig = plt.figure()
ax = Axes3D(fig)
ax.bar(x,y,0,zdir='y',color=clr)
ax.bar(x,y2,10,zdir='y',color=clr) #zdir是图像起来,垂直于y轴
ax.bar(x,y3,20,zdir='y',color=clr)
# ax.bar(x,y4,30,zdir='y',color=clr)
# ax.bar(x,y5,40,zdir='y',color=clr)
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')
ax.view_init(elev=45)

# %%
#在其他紫图中显示紫图

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])

inner_ax = fig.add_axes([0.6,0.6,0.25,0.25])  #左底宽高
x1 = np.arange(10)
y1 = np.array([1,2,7,1,5,2,4,2,3,1])
x2 = np.arange(10)
y2 = np.array([1,3,4,5,4,5,2,6,4,3])
ax.plot(x1,y1)
inner_ax.plot(x2,y2)

# %% [markdown]
# # 自定义 子图网格 ——1

# %%
gs = plt.GridSpec(3,3)  #创建gridspec对象
fig = plt.figure(figsize=(6,6))
x1 = np.array([1,3,2,5])
y1 = np.array([4,3,7,2])
x2 = np.arange(5)
y2 = np.array([3,2,4,6,4])

s1 = fig.add_subplot(gs[1,:2])
s1.plot(x1,y1,'r')

s2 = fig.add_subplot(gs[0,:2])
s2.bar(x2,y2)

s3 = fig.add_subplot(gs[2,0])
s3.barh(x2,y2,color='g')

s4= fig.add_subplot(gs[:2,2])
s4.plot(x2,y2,'k')

s5 = fig.add_subplot(gs[2,1:])
s5.plot(x1,y1,'b^',x2,y2,'yo')

# %% [markdown]
# ## 自定义布局 --2

# %%
fig = plt.figure()
widths = [1,2,1]
heights = [2,2,1]
gs = fig.add_gridspec(3,3,width_ratios=widths,height_ratios=heights)  #指定比例
for row in range(3):
    for col in range(3):
        fig.add_subplot(gs[row,col])
        
fig.tight_layout()

# %% [markdown]
# # matplotlib 的配置
#  1. 动态——修改默认配置

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cycler
import numpy as np
# plt.rcParams['axes.prop_cycle'] = cycler('color',['k','r'])  #默认lines的颜色
# plt.rcParams["font.sans-serif"] = ["FangSong"]  #设置中文
# plt.rcParams["font.size"] = 20 #设置字体大小
plt.style.use('rbp')
plt.plot(np.exp(np.arange(5)))
plt.plot(np.exp(np.random.rand(5)))
plt.title("你好")
# Out:
# Text(0.5, 1.0, '你好')

# %% [markdown]
# #  自定义配置文件

# %%
 # 1,mpl.get_configdir()  #提取配置文件的存放路径
# 2, 在此路径下创建目录 stylelib
# 3,在此路径下创建配置文件 名字.mplstyle 中添加配置
#4. plt.style.use(名字)
plt.style.use('rbp')
plt.plot(np.arange(5))
plt.plot(np.random.rand(5))
plt.title("你好")
# Out:
# Text(0.5, 1.0, '你好')
